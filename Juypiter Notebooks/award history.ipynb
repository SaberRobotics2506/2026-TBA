# %% [markdown]
# ## Original Message
#
# Hi Scouting Friends!
#
# Brayden seemed to enjoy pulling data from TBA using Python so I am giving him extra homework. Will try my best to explain, but as always, please let me know if you have any questions.
#
# The Ask
#
#     Pull the award history from official events from the past 3 years, for our 2 events we are attending.
#     Then analyze/arrange the data in such a way so that we can see
#         Award Name - Number of Times Won Total - Team with Most Wins - #of Times Won - Team with 2nd Most Wins - # of Times Won
#         Sample Data Autonomous Award - 10 - 1732 - 3 - 930 - 2
#
# The Why
#
#     There are a lot of awards that teams can win at these events. Winning awards gets you extra district points that help towards advancement.
#     If we analyze this data and can determine if any are out of reach (say one team dominates that award), or if any awards may be open for business (lower number of overall winners, or lots of ties), then we can position ourselves and target appropriate awards.
#
#
# I think this is a good challenge for anyone interested in pulling different types of data and seeing how best to analyze it. Let me know if you have any questions, comments or concerns.
#
# -Josh
#
# ## TODO
#  - Pull award data for the last 3 years of
#    - Lakland (2026wiply)
#    - Mukwonago (2026wimuk)
#  - Find the following
#    - Award Name
#    - Number of times won over 3 years
#    - Team with most wins
#      - Number of times won
#    - Team with 2nd most wins
#      - Number of times won
#  - Export data as CSV and put into Google Sheet
#    - Sort from there

# %%
import requests
import pandas as pd
import os

API_URL = "https://www.thebluealliance.com/api/v3"
API_KEY = os.getenv("API_KEY_TEAMS")

event_key = input("Enter your team ID here: ")

print(API_KEY)

try:
    response = requests.get(f"{API_URL}/event/{event_key}/awards", headers={'X-TBA-Auth-Key': API_KEY}, timeout=5)
    if not (response.status_code == 200 or 304):
        print(f"Request failed. Please do one of the following: \n 1) Enter a valid team ID \n 2) Check your internet connection (can you access https://www.thebluealliance.com/api/v3) \n 3) Check your API Key\n\n{response.status_code}")
    response = response.json()
    df = pd.json_normalize(response)
    df.to_csv(f"{event_key}_awards.csv", index=False)
    
except Exception as e:
    print(f"Error: {e}")
# Out:
# place keys here
